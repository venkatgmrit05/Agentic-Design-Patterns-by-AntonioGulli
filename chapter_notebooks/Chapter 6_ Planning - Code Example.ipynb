# %%
import os
from dotenv import load_dotenv
from crewai import Agent, Task, Crew, Process
# from langchain_openai import ChatOpenAI
# from langchain_community.llms import Ollama
from langchain_ollama import  OllamaLLM ,ChatOllama


# Load environment variables from .env file for security
# load_dotenv()

# 1. Explicitly define the language model for clarity
# llm = ChatOpenAI(model="gpt-4-turbo")
llm = ChatOllama(model="gemma4")


# 2. Define a clear and focused agent
planner_writer_agent = Agent(
    role='Article Planner and Writer',
    goal='Plan and then write a concise, engaging summary on a specified topic.',
    backstory=(
        'You are an expert technical writer and content strategist. '
        'Your strength lies in creating a clear, actionable plan before writing, '
        'ensuring the final summary is both informative and easy to digest.'
    ),
    verbose=True,
    allow_delegation=False,
    llm='ollama/gemma4' # Assign the specific LLM to the agent
)
# Out:
# Error instantiating LLM from unknown object type: Error importing native provider: OPENAI_API_KEY is required
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File d:\Data\OfficeWorkspace-20191016T044923Z-001\OfficeWorkspace\Agentic-Design-Patterns-by-AntonioGulli\.venv\Lib\site-packages\crewai\llm.py:392, in LLM.__new__(cls, model, is_litellm, **kwargs)
#     389     kwargs_copy = {k: v for k, v in kwargs.items() if k != "provider"}
#     390     return cast(
#     391         Self,
# --> 392         native_class(model=model_string, provider=provider, **kwargs_copy),
#     393     )
#     394 except NotImplementedError:
#
# File d:\Data\OfficeWorkspace-20191016T044923Z-001\OfficeWorkspace\Agentic-Design-Patterns-by-AntonioGulli\.venv\Lib\site-packages\crewai\llms\providers\openai\completion.py:96, in OpenAICompletion.__init__(self, model, api_key, base_url, organization, project, timeout, max_retries, default_headers, default_query, client_params, temperature, top_p, frequency_penalty, presence_penalty, max_tokens, max_completion_tokens, seed, stream, response_format, logprobs, top_logprobs, reasoning_effort, provider, interceptor, **kwargs)
#      86 super().__init__(
#      87     model=model,
#      88     temperature=temperature,
#    (...)     93     **kwargs,
#      94 )
# ---> 96 client_config = self._get_client_params()
#      97 if self.interceptor:
#
# File d:\Data\OfficeWorkspace-20191016T044923Z-001\OfficeWorkspace\Agentic-Design-Patterns-by-AntonioGulli\.venv\Lib\site-packages\crewai\llms\providers\openai\completion.py:125, in OpenAICompletion._get_client_params(self)
#     124     if self.api_key is None:
# --> 125         raise ValueError("OPENAI_API_KEY is required")
#     127 base_params = {
#     128     "api_key": self.api_key,
#     129     "organization": self.organization,
#    (...)    138     "default_query": self.default_query,
#     139 }
#
# ValueError: OPENAI_API_KEY is required
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 18
#      14 llm = ChatOllama(model="gemma4")
#      15
#      16
#      17 # 2. Define a clear and focused agent
# ---> 18 planner_writer_agent = Agent(
#      19     role='Article Planner and Writer',
#      20     goal='Plan and then write a concise, engaging summary on a specified topic.',
#      21     backstory=(
#
#     [... skipping hidden 1 frame]
#
# File d:\Data\OfficeWorkspace-20191016T044923Z-001\OfficeWorkspace\Agentic-Design-Patterns-by-AntonioGulli\.venv\Lib\site-packages\crewai\agent\internal\meta.py:58, in AgentMeta.__new__.<locals>.post_init_setup_with_extensions(self)
#      49 def post_init_setup_with_extensions(self: Any) -> Any:
#      50     """Wrap post_init_setup to apply extensions after initialization.
#      51
#      52     Args:
#    (...)     56         The agent instance
#      57     """
# ---> 58     result = original_func(self)
#      60     a2a_value = getattr(self, "a2a", None)
#      61     if a2a_value is not None:
#
# File d:\Data\OfficeWorkspace-20191016T044923Z-001\OfficeWorkspace\Agentic-Design-Patterns-by-AntonioGulli\.venv\Lib\site-packages\crewai\agent\core.py:225, in Agent.post_init_setup(self)
#     223 @model_validator(mode="after")
#     224 def post_init_setup(self) -> Self:
# --> 225     self.llm = create_llm(self.llm)
#     226     if self.function_calling_llm and not isinstance(
#     227         self.function_calling_llm, BaseLLM
#     228     ):
#     229         self.function_calling_llm = create_llm(self.function_calling_llm)
#
# File d:\Data\OfficeWorkspace-20191016T044923Z-001\OfficeWorkspace\Agentic-Design-Patterns-by-AntonioGulli\.venv\Lib\site-packages\crewai\utilities\llm_utils.py:66, in create_llm(llm_value)
#      64 except Exception as e:
#      65     logger.error(f"Error instantiating LLM from unknown object type: {e}")
# ---> 66     raise e
#
# File d:\Data\OfficeWorkspace-20191016T044923Z-001\OfficeWorkspace\Agentic-Design-Patterns-by-AntonioGulli\.venv\Lib\site-packages\crewai\utilities\llm_utils.py:53, in create_llm(llm_value)
#      50     base_url: str | None = getattr(llm_value, "base_url", None)
#      51     api_base: str | None = getattr(llm_value, "api_base", None)
# ---> 53     return LLM(
#      54         model=model,
#      55         temperature=temperature,
#      56         max_tokens=max_tokens,
#      57         logprobs=logprobs,
#      58         timeout=timeout,
#      59         api_key=api_key,
#      60         base_url=base_url,
#      61         api_base=api_base,
#      62     )
#      64 except Exception as e:
#      65     logger.error(f"Error instantiating LLM from unknown object type: {e}")
#
# File d:\Data\OfficeWorkspace-20191016T044923Z-001\OfficeWorkspace\Agentic-Design-Patterns-by-AntonioGulli\.venv\Lib\site-packages\crewai\llm.py:397, in LLM.__new__(cls, model, is_litellm, **kwargs)
#     395         raise
#     396     except Exception as e:
# --> 397         raise ImportError(f"Error importing native provider: {e}") from e
#     399 # FALLBACK to LiteLLM
#     400 if not LITELLM_AVAILABLE:
#
# ImportError: Error importing native provider: OPENAI_API_KEY is required

# %%
# 3. Define a task with a more structured and specific expected output
topic = "The importance of Reinforcement Learning in AI"
high_level_task = Task(
    description=(
        f"1. Create a bullet-point plan for a summary on the topic: '{topic}'.\n"
        f"2. Write the summary based on your plan, keeping it around 200 words."
    ),
    expected_output=(
        "A final report containing two distinct sections:\n\n"
        "### Plan\n"
        "- A bulleted list outlining the main points of the summary.\n\n"
        "### Summary\n"
        "- A concise and well-structured summary of the topic."
    ),
    agent=planner_writer_agent,
)

# %%
# Create the crew with a clear process
crew = Crew(
    agents=[planner_writer_agent],
    tasks=[high_level_task],
    process=Process.sequential,
)

# %%
# Execute the task
print("## Running the planning and writing task ##")
result = crew.kickoff()

print("\n\n---\n## Task Result ##\n---")
print(result)
